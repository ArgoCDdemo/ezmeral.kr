# %% [markdown]
# # Lab 1 Setup and Test
# In this lab we will:
# 1. introduce and test the line magic functions that are apart of Ezmeral MLOps
# 2. populate our project repository with the necessary files
#
# <b>Line magics</b>, which are denoted by a single % prefix, operate on a single line of input.
#
# <b>Cell magics</b>, which are denoted by a double %% prefix, operate on multiple lines of input.

# %%
# %kubeRefresh

# %% [markdown]
# ### Livy Magic
#
# %setLivy magic is used to set Livy URL in spark magic config.json. This is need to set 1 time for a logged in user. If you want to update Livy Url then you can use the same magic.
#
# [Custom Magics](https://docs.containerplatform.hpe.com/53/reference/kubernetes/using-kubernetes/general-functionality/tutorials/general/Tutorial_Connect_to_Livy_with_Spark_Magic.html?hl=%25setlivy)

# %% [markdown]
# ![image.png](attachment:78165f4a-ddcd-4044-a828-ccdadd44c36e.png)

# %%
# %setLivy --url <livy url here>

# %% [markdown]
# # Populating Tenant Storage
#
# In an ideal situation, your project administrator would populate the tenant storage with your required dataset. However, since this is a tutorial, we will need to manually download the file and populate our Tenant Storage.
#
# 1. Download the /Data/T1.csv file
# 2. Navigate to the ECP UI and look for DataTaps
# 3. Click the green "TenantStorage" link
# 4. Create the following directory dtap://TenantStorage/Scada-Dataset
# 5. Upload th

# %% [markdown]
# # Continue onto Lab 2 for some data engineering work!
