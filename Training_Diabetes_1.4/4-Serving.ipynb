# %% [markdown]
# # Lab 4 Serving
# 1. Register model
# 2. Create model serving cluster
# 3. Test inference

# %% [markdown]
# ## 1. Register Model
# Navigate to your ECP tenant
#
# Click on "Model Registry"
#
# Click on Register New Model button (green button)

# %% [markdown]
# ![image.png](attachment:a8c0d4cf-75c9-4db2-8451-2b405ef6165a.png)

# %% [markdown]
# ## Fill in the fields for your model
# ![image.png](attachment:ff77a225-77cc-4bc7-9d33-73fa9d2d73c0.png)

# %% [markdown]
# ## Create Model Serving Cluster
# ![image.png](attachment:6c25408d-b630-4a3e-85be-9c99faf3e2e5.png)

# %% [markdown]
# ## Choose your model and resources
# ![image.png](attachment:41b09660-d9b2-47d7-adec-7d7ace19232e.png)

# %% [markdown]
# ## Grab serving endpoint
# ![image.png](attachment:1c7dadc3-c683-4223-a3fe-a44b511094ea.png)

# %% [markdown]
# ## Inference
# - Replace "A" with your serving endpoint found in the "Model Serving Lodbalancer" service
# - Replace "B" with your model name
# - Replace "C" with your model version
# - Replace "D" with your auth token found in the "Model Serving LoadBalancer"

# %%
# %%bash
#
# curl --location -k -s --request POST A/B/C/predict \
# --header "X-Auth-Token: <D>" \
# --header 'Content-Type: application/json' \
# -d ' {
#     "use_scoring" : true,
#     "scoring_args" : {
#         "NumPreg":1.0,
#         "Glucose": 85.0,
#         "BloodPressure": 66.0,
#         "SkinThick": 29.0,
#         "Insulin": 0.0,
#         "BMI": 26.6,
#         "DiabetesPedFunc": 0.351,
#         "Age": 35.0
#     }
# }' | python -m json.tool | grep output | cut -d'\' -f 1

# %% [markdown]
# # Once you are done with the inference, please delete the model_serving cluster
